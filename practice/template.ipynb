# %% [markdown]
# # 실습 제목
#
# - 기준 TIL: [YYYY-MM-DD](<날짜별 TIL 상대 경로>)
# - 관련 강의자료: [자료명](<강의자료 상대 경로>)
# - 강의 제공 실습: 해당할 때만 정확한 INDEX 매핑 경로를 추가
# - 난이도: Core / Applied / Advanced
# - 상태: 시작 전
#
# ## 왜 지금 이 실습을 하는가
#
# 오늘 배운 내용을 회상하고 바닥부터 구현해 실제 동작과 실패를 설명합니다.
#
# ## Practice Coverage Map
#
# | Outcome ID | TIL location | Practice action | Artifact/Exercise | Required evidence |
# | --- | --- | --- | --- | --- |
# | O01 | 오늘의 학습 > 정확한 구절 | implement | E01 | 구현, 테스트, 결과 해석 |

# %%
# setup-check: notebook-only imports
import numpy as np

# %% [markdown]
# ## E01. 실습 제목
#
# ### 실제 사용 맥락
#
# 이 계약이 필요한 작은 상황과 요구사항을 적습니다.
#
# ### 실행 전 회상·예측
#
# - 실행 전에 예상한 값 또는 Shape:
# - 그렇게 예상한 이유:
#
# ### 작은 유사 사례와 계약
#
# 결정적인 작은 입출력, dtype, Shape, 오류 계약을 적습니다.
#
# ### 구현
#
# 바로 아래 셀에서 학습 대상 함수를 바닥부터 구현합니다.
#
# <details>
# <summary>힌트 1: 관찰할 상태와 개념</summary>
#
# 먼저 확인할 한 가지 상태를 적습니다.
# </details>
#
# <details>
# <summary>힌트 2: 작은 trace 또는 Shape 흐름</summary>
#
# 완성 구현 없이 작은 흐름이나 pseudocode만 적습니다.
# </details>

# %%
# TODO: E01
def learner_function(value: np.ndarray) -> np.ndarray:
    """Describe the learner-owned public contract."""
    raise NotImplementedError("learner implementation")

# %%
# provided-fixture: E01
fixture = np.array([0.0])  # 이 문제의 deterministic input으로 교체
observed = learner_function(fixture)
print("observed:", observed)

# %% [markdown]
# ### 테스트와 실패 진단
#
# 아래 검사 함수로 정상·경계·실패 계약을 확인하고 첫 실패의 상태를 적습니다.

# %%
# test-check: E01
def check_e01() -> None:
    # normal
    # provide a normal contract check

    # edge
    # provide an edge contract check

    # failure
    # provide a failure contract check
    raise NotImplementedError("provide the exercise contract checks")


check_e01()

# %% [markdown]
# ### 결과 해석
#
# - 실제 결과와 실행 전 예상의 차이:
# - 이 결과가 시스템 계약에 대해 보여주는 것:
# - 이 구현의 한계 또는 다음 실패 사례:
