# %% [markdown]
# # 실습 제목
#
# - 기준 TIL: [YYYY-MM-DD](<날짜별 TIL 상대 경로>)
# - 관련 강의자료: [자료명](<강의자료 상대 경로>)
# - 난이도: Core / Applied / Advanced
# - 상태: 시작 전

# %% [markdown]
# ## 왜 지금 이 실습을 하는가
#
# - TIL에서 확인된 이해:
# - 이번에 확인할 부족한 부분:
# - 핵심 질문:

# %% [markdown]
# ## 목표와 완료 기준
#
# - [ ] 직접 구현하거나 계산했다.
# - [ ] 결과가 예상과 같거나 다른 이유를 설명했다.
# - [ ] 한계 또는 실패 사례 하나를 찾았다.
# - [ ] 배운 내용을 내 말로 정리했다.

# %% [markdown]
# ## 실행 전 예상
#
# 코드를 실행하기 전에 결과를 먼저 예상합니다.
#
# - 예상 결과:
# - 그렇게 예상한 이유:
# - 비교할 때 같게 유지할 조건:

# %%
# 준비
# 필요한 라이브러리를 불러오고 재현성을 위한 설정을 작성하세요.
# TODO

# %% [markdown]
# ## 1. 기준 실험
#
# 무엇을 계산하거나 구현해야 하는지 단계별 지시를 적습니다.
#
# <details>
# <summary>막혔을 때 힌트</summary>
#
# 최소 힌트 → 부분 설정 순서로 적고 완성 답안은 넣지 않습니다.
# </details>

# %%
# 기준 실험
# TODO: 직접 계산하거나 구현하세요.

# %% [markdown]
# ## 2. 적용 또는 심화
#
# Applied라면 조건 하나를 바꿔 비교하고, Advanced라면 명시한 가설을 ablation·민감도·실패 사례·효율 비교 중 하나로 검증합니다. Core 워크북에서는 이 절을 제거합니다.
#
# - 가설 또는 바꿀 조건:
# - 관찰할 값:

# %%
# 적용 또는 심화 실험
# TODO: 선택한 조건만 바꿔 비교하세요.

# %% [markdown]
# ## 결과 해석과 마무리
#
# - 실제 결과:
# - 예상과 같거나 달랐던 이유:
# - 이 결과가 개념에 대해 보여주는 것:
# - 이 실험의 한계 또는 실패 사례:
# - 추가로 확인할 점(선택, 없으면 생략):
